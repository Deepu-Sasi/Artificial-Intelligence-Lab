# %%
import numpy as np
import statistics
n=int(input("Enter the number of numbers to be added in array :"))
a=[]
for i in range(0,n):
    a.append(int(input()))

#to find mean
c=len(a)
s=0
for i in a:
    s=s+i
mean=s/c
print("Mean :",mean)

#to find median
a.sort()
if c%2==0:
    m1=a[n//2]
    m2=a[n//2-1]
    median=(m1+m2)/2
else:
    median=a[n//2]
print("Median :",median)

#to find mod
max=(0,0)
for i in a:
    occur=a.count(i)
    if occur > max[0]:
        max=(occur, i)
print("Mode :",max[1])

#to find standard deviation
print("Standard deviation :",(statistics.stdev(a)))

#to find percentile
p=int(input("Enter the no of percentile:"))
print("Percentile :",np.percentile(a, 50))
# Out:
# Enter the number of numbers to be added in array :4
# 2
# 6
# 5
# 3
# Mean : 4.0
# Median : 4.0
# Mode : 2
# Standard deviation : 1.8257418583505538
# Enter the no of percentile:25
# Percentile : 4.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics 
x_axis=np.arange(-20, 20, 0.01)
mean=statistics.mean(x_axis)
sd=statistics.stdev(x_axis)
plt.plot(x_axis, norm.pdf(x_axis, mean, sd))
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"]=[7.50,3.50]
plt.rcParams["figure.autolayout"]=True
N=500
data=np.random.randn(N)
count,bins_count=np.histogram(data, bins=10)
pdf=count/sum(count)
cdf=np.cumsum(pdf)
plt.plot(bins_count[1:], cdf, label="CDF")
plt.legend()
plt.show()
